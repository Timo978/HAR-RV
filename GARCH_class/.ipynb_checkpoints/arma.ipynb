# %%
import pandas as pd
import numpy as np
import statsmodels.tsa.api as smt     
#tsa为Time Series analysis缩写
import statsmodels.api as sm
import scipy.stats as scs
from arch import arch_model
#画图
import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline
#正常显示画图时出现的中文和负号
from pylab import mpl
mpl.rcParams['font.sans-serif']=['Heiti TC']
mpl.rcParams['axes.unicode_minus']=False

import warnings
warnings.filterwarnings('ignore')

# %%
#先定义一个画图函数，后面都会用到

def ts_plot(data, lags=None,title=''):
    if not isinstance(data, pd.Series):   
        data = pd.Series(data)
    #matplotlib官方提供了五种不同的图形风格，
    #包括bmh、ggplot、dark_background、fivethirtyeight和grayscale
    with plt.style.context('ggplot'):    
        fig = plt.figure(figsize=(10, 8))
        layout = (3, 2)
        ts_ax = plt.subplot2grid(layout, (0, 0), colspan=2)
        acf_ax = plt.subplot2grid(layout, (1, 0))
        pacf_ax = plt.subplot2grid(layout, (1, 1))
        qq_ax = plt.subplot2grid(layout, (2, 0))
        pp_ax = plt.subplot2grid(layout, (2, 1))
        data.plot(ax=ts_ax)
        ts_ax.set_title(title+'时序图')
        smt.graphics.plot_acf(data, lags=lags, ax=acf_ax, alpha=0.5)
        acf_ax.set_title('自相关系数')
        smt.graphics.plot_pacf(data, lags=lags, ax=pacf_ax, alpha=0.5)
        pacf_ax.set_title('偏自相关系数')
        sm.qqplot(data, line='s', ax=qq_ax)
        qq_ax.set_title('QQ 图')        
        scs.probplot(data, sparams=(data.mean(), 
                     data.std()), plot=pp_ax)
        pp_ax.set_title('PP 图') 
        plt.tight_layout()
    return

# %%
# 模拟AR(1) 过程 
#设置随机种子（括号里数字无意义）
np.random.seed(1)
#模拟次数
n=5000
#AR模型的参数
a = 0.8
#扰动项为正态分布
x = w = np.random.normal(size=n)
for t in range(1,n):
    x[t] = a*x[t-1] + w[t]
#画图
ts_plot(x, lags=30)

# %%
#估计数据的AR模型参数和滞后阶数
def simu_ar(data,a,maxlag=30,true_order = 1):
    '''data:要拟合的数据；a为参数,可以为列表；maxlag:最大滞后阶数'''
    # 拟合AR(p)模型
    result = smt.AR(data).fit(maxlag=maxlag, ic='aic', trend='nc')
    #选择滞后阶数
    est_order = smt.AR(data).select_order(maxlag=maxlag,
                ic='aic', trend='nc')  
    #参数选择标准ic : 有四个选择 {‘aic’,’bic’,’hqic’,’t-stat’}
    #趋势项：trend：c是指包含常数项，nc为不含常数项
    #打印结果
    print(f'参数估计值：{result.params.round(2)}，估计的滞后阶数：{est_order}')
    print(f'真实参数值：{a}，真实滞后阶数 {true_order}')

simu_ar(x,a=0.8)
# Out:
# 参数估计值：[0.8]，估计的滞后阶数：1
# 真实参数值：0.8，真实滞后阶数 1

# %%
# Select best lag order for hs300 returns
import tushare as ts
token='3a5d8df1d0f8bbbe5bd54664417eaf8b60f4bfea4a8551f2926f8019'
pro=ts.pro_api(token)
df=pro.index_daily(ts_code='000300.SH')
df.index=pd.to_datetime(df.trade_date)
df=df.sort_index()
df['ret']=np.log(df.close/df.close.shift())
max_lag = 30
Y=df.ret.dropna()
ts_plot(Y,lags=max_lag,title='沪深300')
result = smt.AR(Y.values).fit(maxlag=max_lag, ic='aic', trend='nc')
est_order = smt.AR(Y.values).select_order(maxlag=max_lag, 
            ic='aic', trend='nc')
print(f'沪深300拟合AR模型的参数：{result.params.round(2)}')
print(f'沪深300拟合AR模型的最佳滞后阶数 {est_order}')
# Out:
# 沪深300拟合AR模型的参数：[ 0.03 -0.02  0.03  0.04  0.   -0.06  0.03  0.    0.01  0.01  0.02  0.02
#   0.05 -0.03  0.04]
# 沪深300拟合AR模型的最佳滞后阶数 15

# %%
#这里使用arma模型进行模拟，设定ar阶数为0，即得到ma模型
alphas = np.array([0.])
betas = np.array([0.6])
ar = np.r_[1, -alphas]
ma = np.r_[1, betas]
#模拟MA的样本数据
ma_sample = smt.arma_generate_sample(ar=ar, ma=ma, nsample=1000) 
ts_plot(ma_sample, lags=30,title='MA(1)模型')

# %%
# 对上述模拟数据进行ARMA模型拟合
max_lag = 30
result = smt.ARMA(ma1, order=(0, 1)).fit(maxlag=max_lag, 
             method='mle', trend='nc')
print(result.summary())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/kb/1kf8hw_j5z585qrzxggc650r0000gq/T/ipykernel_70010/4113947185.py in <cell line: 3>()
#       1 # 对上述模拟数据进行ARMA模型拟合
#       2 max_lag = 30
# ----> 3 result = smt.ARMA(ma1, order=(0, 1)).fit(maxlag=max_lag,
#       4              method='mle', trend='nc')
#       5 print(result.summary())
#
# NameError: name 'ma1' is not defined

# %%
max_lag = 30
result=smt.ARMA(Y.values,order=(0,3)).fit(maxlag=max_lag, 
         method='mle', trend='nc')
print(result.summary())
resid=pd.Series(result.resid,index=Y.index)
ts_plot(resid, lags=max_lag,title='沪深300指数MA拟合残差')
# Out:
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.67109D+00    |proj g|=  1.13936D-03
#
# At iterate    5    f= -2.67109D+00    |proj g|=  8.88178D-08
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      5     10      1     0     0   8.882D-08  -2.671D+00
#   F =  -2.6710944975337707
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 4263
# Model:                     ARMA(0, 3)   Log Likelihood               11386.876
# Method:                           mle   S.D. of innovations              0.017
# Date:                Thu, 21 Jul 2022   AIC                         -22765.752
# Time:                        16:33:12   BIC                         -22740.321
# Sample:                             0   HQIC                        -22756.766
#
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1.y        0.0237      0.015      1.543      0.123      -0.006       0.054
# ma.L2.y       -0.0235      0.015     -1.595      0.111      -0.052       0.005
# ma.L3.y        0.0295      0.016      1.799      0.072      -0.003       0.062
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# MA.1           -2.9151           -0.0000j            2.9151           -0.5000
# MA.2            1.8555           -2.8599j            3.4091           -0.1584
# MA.3            1.8555           +2.8599j            3.4091            0.1584
# -----------------------------------------------------------------------------

# %%
# 下面使用ARMA(2, 2) 模型进行模拟分析
max_lag = 30
n = 5000
burn = int(n/10) 
alphas = np.array([0.5, -0.25])
betas = np.array([0.5, -0.3])
#注意ar模型1代表0阶（自身），然后在其他系数前加负号
ar = np.r_[1, -alphas]
ma = np.r_[1, betas]
arma22 = smt.arma_generate_sample(ar=ar, ma=ma, nsample=n, burnin=burn)
_ = ts_plot(arma22, lags=max_lag)
result = smt.ARMA(arma22, order=(2, 2)).fit(maxlag=max_lag, 
         method='mle', trend='nc', burnin=burn)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/kb/1kf8hw_j5z585qrzxggc650r0000gq/T/ipykernel_70010/1126322094.py in <cell line: 12>()
#      10 arma22 = smt.arma_generate_sample(ar=ar, ma=ma, nsample=n, burnin=burn)
#      11 _ = ts_plot(arma22, lags=max_lag)
# ---> 12 result = smt.ARMA(arma22, order=(2, 2)).fit(maxlag=max_lag,
#      13          method='mle', trend='nc', burnin=burn)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/arima_model.py in fit(self, start_params, trend, method, transparams, solver, maxiter, full_output, disp, callback, start_ar_lags, **kwargs)
#    1014             start_params = array_like(start_params, 'start_params')
#    1015         else:  # estimate starting parameters
# -> 1016             start_params = self._fit_start_params((k_ar, k_ma, k), method,
#    1017                                                   start_ar_lags)
#    1018
#
# ~/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/arima_model.py in _fit_start_params(self, order, method, start_ar_lags)
#     601     def _fit_start_params(self, order, method, start_ar_lags=None):
#     602         if method != 'css-mle':  # use Hannan-Rissanen to get start params
# --> 603             start_params = self._fit_start_params_hr(order, start_ar_lags)
#     604         else:  # use CSS to get start params
#     605             def func(params):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/arima_model.py in _fit_start_params_hr(self, order, start_ar_lags)
#     539                     if maxlag >= nobs:
#     540                         maxlag = nobs - 1
# --> 541                     mod = ar_select_order(endog, maxlag, trend='n',
#     542                                           old_names=False).model
#     543                     armod = mod.fit()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/ar_model.py in ar_select_order(endog, maxlag, ic, glob, trend, seasonal, exog, hold_back, period, missing, old_names)
#    2701             sel[base_col : base_col + i] = True
#    2702             if not np.any(sel):
# -> 2703                 ics.append((0, ic_no_data()))
#    2704                 continue
#    2705             res = OLS(y, x[:, sel]).fit()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/ar_model.py in ic_no_data()
#    2694         )
#    2695
# -> 2696         return compute_ics(res)
#    2697
#    2698     if not glob:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/ar_model.py in compute_ics(res)
#    2678         res = SimpleNamespace(nobs=nobs, df_model=df_model, sigma2=sigma2)
#    2679
# -> 2680         aic = AutoRegResults.aic.func(res)
#    2681         bic = AutoRegResults.bic.func(res)
#    2682         hqic = AutoRegResults.hqic.func(res)
#
# AttributeError: 'pandas._libs.properties.CachedProperty' object has no attribute 'func'

# %%
#不事先确定滞后阶数，而是通过信息准则选择最佳的滞后阶数
#先将初始值设置为无穷大
best_aic = np.inf 
best_order = None
best_mdl = None
rng = range(5)
for i in rng:
    for j in rng:
        try:
            tmp_mdl = smt.ARMA(Y.values, order=(i,j)).fit(method='mle', trend='nc')
            tmp_aic = tmp_mdl.aic
            if tmp_aic < best_aic:
                best_aic = tmp_aic
                best_order = (i, j)
                best_mdl = tmp_mdl
        except: continue
print(f'最佳滞后阶数:{best_order}')
print(best_mdl.summary())
resid=pd.Series(best_mdl.resid,index=Y.index)
ts_plot(resid, lags=30,title='沪深300指数ARMA拟合残差')
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            1     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.67040D+00    |proj g|=  8.36087D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     1      2      4      1     0     0   0.000D+00  -2.670D+00
#   F =  -2.6704055665461497
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.67071D+00    |proj g|=  8.42082D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      4      8      1     0     0   0.000D+00  -2.671D+00
#   F =  -2.6707152639949974
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.67109D+00    |proj g|=  1.13936D-03
#
# At iterate    5    f= -2.67109D+00    |proj g|=  8.88178D-08
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      5     10      1     0     0   8.882D-08  -2.671D+00
#   F =  -2.6710944975337707
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.67195D+00    |proj g|=  2.87135D-03
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
# At iterate    5    f= -2.67197D+00    |proj g|=  8.88178D-08
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4      6      9      1     0     0   8.882D-08  -2.672D+00
#   F =  -2.6719724897432569
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            1     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.67039D+00    |proj g|=  2.00728D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     1      3      6      1     0     0   8.882D-08  -2.670D+00
#   F =  -2.6703887787675837
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.67071D+00    |proj g|=  2.12941D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      7      1     0     0   1.776D-07  -2.671D+00
#   F =  -2.6707066534618695
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#  This problem is unconstrained.
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.67113D+00    |proj g|=  2.01661D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      4      6      1     0     0   8.882D-08  -2.671D+00
#   F =  -2.6711313413332753
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.67213D+00    |proj g|=  1.84475D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4      4      6      1     0     0   1.776D-07  -2.672D+00
#   F =  -2.6721315914994759
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#  This problem is unconstrained.
# 最佳滞后阶数:(4, 0)
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 4263
# Model:                     ARMA(4, 0)   Log Likelihood               11391.297
# Method:                           mle   S.D. of innovations              0.017
# Date:                Thu, 21 Jul 2022   AIC                         -22772.594
# Time:                        16:33:53   BIC                         -22740.805
# Sample:                             0   HQIC                        -22761.362
#
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1.y        0.0250      0.015      1.634      0.102      -0.005       0.055
# ar.L2.y       -0.0248      0.015     -1.621      0.105      -0.055       0.005
# ar.L3.y        0.0279      0.015      1.827      0.068      -0.002       0.058
# ar.L4.y        0.0447      0.015      2.922      0.003       0.015       0.075
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            2.0625           -0.0000j            2.0625           -0.0000
# AR.2           -0.1162           -2.0987j            2.1019           -0.2588
# AR.3           -0.1162           +2.0987j            2.1019            0.2588
# AR.4           -2.4554           -0.0000j            2.4554           -0.5000
# -----------------------------------------------------------------------------

# %%
#原理与拟合ARMA模型类似
best_aic = np.inf 
best_order = None
best_mdl = None
#假定最多滞后4阶
pq_rng = range(5) 
#假定最多差分一次
d_rng = range(2) 
for i in pq_rng:
    for d in d_rng:
        for j in pq_rng:
            try:
                tmp_mdl = smt.ARIMA(Y.values, order=(i,d,j)).fit(method='mle', trend='nc')
                tmp_aic = tmp_mdl.aic
                if tmp_aic < best_aic:
                    best_aic = tmp_aic
                best_order = (i, d, j)
                best_mdl = tmp_mdl
            except: continue
print(f'ARIMA模型最佳阶数选择：{best_order}')
# 对拟合残差进行可视化
print(best_mdl.summary())
resid=pd.Series(best_mdl.resid,index=Y.index)
ts_plot(resid, lags=30,title='沪深300指数ARIMA残差')
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            1     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.67040D+00    |proj g|=  8.36087D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     1      2      4      1     0     0   0.000D+00  -2.670D+00
#   F =  -2.6704055665461497
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.67071D+00    |proj g|=  8.42082D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      4      8      1     0     0   0.000D+00  -2.671D+00
#   F =  -2.6707152639949974
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.67109D+00    |proj g|=  1.13936D-03
#
# At iterate    5    f= -2.67109D+00    |proj g|=  8.88178D-08
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      5     10      1     0     0   8.882D-08  -2.671D+00
#   F =  -2.6710944975337707
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.67195D+00    |proj g|=  2.87135D-03
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
# At iterate    5    f= -2.67197D+00    |proj g|=  8.88178D-08
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4      6      9      1     0     0   8.882D-08  -2.672D+00
#   F =  -2.6719724897432569
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#  This problem is unconstrained.
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            1     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.52382D+00    |proj g|=  1.29261D-01
#
# At iterate    5    f= -2.66908D+00    |proj g|=  2.08105D-03
#
# At iterate   10    f= -2.66957D+00    |proj g|=  2.66454D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     1     11     12      1     0     0   0.000D+00  -2.670D+00
#   F =  -2.6695670055233776
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.56407D+00    |proj g|=  9.69415D-02
#
# At iterate    5    f= -2.66944D+00    |proj g|=  1.39297D-03
#
# At iterate   10    f= -2.66971D+00    |proj g|=  3.59712D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2     12     19      1     0     0   8.882D-08  -2.670D+00
#   F =  -2.6697128432991613
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.58135D+00    |proj g|=  7.49505D-02
#
# At iterate    5    f= -2.66544D+00    |proj g|=  1.69480D-02
#
# At iterate   10    f= -2.67027D+00    |proj g|=  5.46230D-05
#  This problem is unconstrained.
#
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
#  This problem is unconstrained.
# At iterate   15    f= -2.67027D+00    |proj g|=  1.33227D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     15     28      1     0     0   1.332D-07  -2.670D+00
#   F =  -2.6702650623084323
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.58244D+00    |proj g|=  7.14915D-02
#
# At iterate    5    f= -2.66630D+00    |proj g|=  7.51181D-03
#
# At iterate   10    f= -2.67043D+00    |proj g|=  1.13696D-03
#
# At iterate   15    f= -2.67044D+00    |proj g|=  4.44089D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     17     26      1     0     0   1.776D-07  -2.670D+00
#   F =  -2.6704411272747635
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            1     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.67039D+00    |proj g|=  2.00728D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     1      3      6      1     0     0   8.882D-08  -2.670D+00
#   F =  -2.6703887787675837
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#  This problem is unconstrained.
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            1     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.46361D+00    |proj g|=  5.14699D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     1      3      7      1     0     0   0.000D+00  -2.464D+00
#   F =  -2.4636143466186904
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.67071D+00    |proj g|=  2.12941D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      7      1     0     0   1.776D-07  -2.671D+00
#   F =  -2.6707066534618695
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#  This problem is unconstrained.
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.53225D+00    |proj g|=  1.40155D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      4      6      1     0     0   0.000D+00  -2.532D+00
#   F =  -2.5322463664086188
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.67113D+00    |proj g|=  2.01661D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      4      6      1     0     0   8.882D-08  -2.671D+00
#   F =  -2.6711313413332753
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.57188D+00    |proj g|=  2.01705D-04
#
# At iterate    5    f= -2.57188D+00    |proj g|=  8.88178D-08
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      6      8      1     0     0   0.000D+00  -2.572D+00
#   F =  -2.5718825501450806
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.67213D+00    |proj g|=  1.84475D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4      4      6      1     0     0   1.776D-07  -2.672D+00
#   F =  -2.6721315914994759
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.58854D+00    |proj g|=  2.47979D-04
#
# At iterate    5    f= -2.58854D+00    |proj g|=  1.33227D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4      7     10      1     0     0   1.776D-07  -2.589D+00
#   F =  -2.5885390918788262
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#  This problem is unconstrained.
# ARIMA模型最佳阶数选择：(4, 1, 0)
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                    D.y   No. Observations:                 4262
# Model:                 ARIMA(4, 1, 0)   Log Likelihood               11032.354
# Method:                           mle   S.D. of innovations              0.018
# Date:                Thu, 21 Jul 2022   AIC                         -22054.707
# Time:                        16:37:09   BIC                         -22022.920
# Sample:                             1   HQIC                        -22043.476
#
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1.D.y     -0.7934      0.015    -52.664      0.000      -0.823      -0.764
# ar.L2.D.y     -0.6331      0.018    -34.588      0.000      -0.669      -0.597
# ar.L3.D.y     -0.4106      0.018    -22.435      0.000      -0.446      -0.375
# ar.L4.D.y     -0.1810      0.015    -12.016      0.000      -0.211      -0.151
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            0.2284           -1.4164j            1.4347           -0.2246
# AR.2            0.2284           +1.4164j            1.4347            0.2246
# AR.3           -1.3626           -0.9097j            1.6384           -0.4063
# AR.4           -1.3626           +0.9097j            1.6384            0.4063
# -----------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/kb/1kf8hw_j5z585qrzxggc650r0000gq/T/ipykernel_70010/1575839200.py in <cell line: 23>()
#      21 # 对拟合残差进行可视化
#      22 print(best_mdl.summary())
# ---> 23 resid=pd.Series(best_mdl.resid,index=Y.index)
#      24 ts_plot(resid, lags=30,title='沪深300指数ARIMA残差')
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     440                 index = default_index(len(data))
#     441             elif is_list_like(data):
# --> 442                 com.require_length_match(data, index)
#     443
#     444             # create/copy the manager
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/common.py in require_length_match(data, index)
#     555     """
#     556     if len(data) != len(index):
# --> 557         raise ValueError(
#     558             "Length of values "
#     559             f"({len(data)}) "
#
# ValueError: Length of values (4262) does not match length of index (4263)

# %%
# 对沪深300收益率未来20天进行预测
n_steps = 20
#分别设置95%和99%的置信度
f, err95, ci95 = best_mdl.forecast(steps=n_steps) 
_, err99, ci99 = best_mdl.forecast(steps=n_steps, alpha=0.01) 
date=(df.index[-1]).strftime('%Y%m%d')
cal=pro.trade_cal(exchange='', start_date=date)
idx = cal[cal.is_open==1][:20]['cal_date'].values
fc_95 = pd.DataFrame(np.column_stack([f, ci95]), 
index=idx,columns=['forecast', 'lower_ci_95', 'upper_ci_95'])
fc_99 = pd.DataFrame(np.column_stack([ci99]), 
      index=idx, columns=['lower_ci_99', 'upper_ci_99'])
fc_all = fc_95.combine_first(fc_99)
#fc_all.head()

# 对预测的20日收益率数据进行可视化
plt.style.use('ggplot')
fig = plt.figure(figsize=(12,7))
ax = plt.gca()
ts = df['ret'][-500:].copy()
ts.plot(ax=ax, label='HS300收益率')
# 样本内预测
pred=best_mdl.predict(np.arange(len(ts)) [0], np.arange(len(ts))[-1])
pf=pd.Series(pred,index=ts.index)
pf.plot(ax=ax, style='r-', label='样本内预测')
fc_all.index=pd.to_datetime(fc_all.index)
fc_all.plot(ax=ax)
plt.fill_between(fc_all.index, fc_all.lower_ci_95, 
     fc_all.upper_ci_95, color='gray', alpha=0.7)
plt.fill_between(fc_all.index, fc_all.lower_ci_99, 
     fc_all.upper_ci_99, color='gray', alpha=0.2)
plt.title('{} 天HS300收益率预测\nARIMA{}'.format(n_steps, 
     best_order))
plt.legend(loc='best', fontsize=10)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/kb/1kf8hw_j5z585qrzxggc650r0000gq/T/ipykernel_70010/3082465097.py in <cell line: 23>()
#      21 ts.plot(ax=ax, label='HS300收益率')
#      22 # 样本内预测
# ---> 23 pred=best_mdl.predict(np.arange(len(ts)) [0], np.arange(len(ts))[-1])
#      24 pf=pd.Series(pred,index=ts.index)
#      25 pf.plot(ax=ax, style='r-', label='样本内预测')
#
# ~/opt/anaconda3/lib/python3.9/site-packages/statsmodels/base/wrapper.py in wrapper(self, *args, **kwargs)
#     111             obj = data.wrap_output(func(results, *args, **kwargs), how[0], how[1:])
#     112         elif how:
# --> 113             obj = data.wrap_output(func(results, *args, **kwargs), how)
#     114         return obj
#     115
#
# ~/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/arima_model.py in predict(self, start, end, exog, typ, dynamic)
#    1888     def predict(self, start=None, end=None, exog=None, typ='linear',
#    1889                 dynamic=False):
# -> 1890         return self.model.predict(self.params, start, end, exog, typ, dynamic)
#    1891
#    1892     def _forecast_error(self, steps):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/arima_model.py in predict(self, params, start, end, exog, typ, dynamic)
#    1256             if not dynamic or (start != self.k_ar + self.k_diff and
#    1257                                start is not None):
# -> 1258                 return super(ARIMA, self).predict(params, start, end, exog,
#    1259                                                   dynamic)
#    1260             else:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/arima_model.py in predict(self, params, start, end, exog, dynamic, **kwargs)
#     766         # will return an index of a date
#     767         start, end, out_of_sample, _ = (
# --> 768             self._get_prediction_index(start, end, dynamic))
#     769
#     770         if out_of_sample and (exog is None and self.k_exog > 0):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/arima_model.py in _get_prediction_index(self, start, end, dynamic, index)
#    1128             start -= k_diff
#    1129             if start < 0:
# -> 1130                 raise ValueError('The start index %d of the original series '
#    1131                                  ' has been differenced away' % start)
#    1132         if isinstance(end, (int, np.integer)):
#
# ValueError: The start index -1 of the original series  has been differenced away
